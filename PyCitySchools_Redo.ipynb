# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Setup
import pandas as pd

# File to Load
Sxhool_Data = "Resources/schools_complete.csv"
student_DatX = "Resources/students_complete.csv"

# %%
# Read School and Student Files,store in pandas as data frame
sxhool_Data = pd.read_csv(Sxhool_Data)
student_DatX = pd.read_csv(student_DatX)

# merge the data into one data set  
sxhool_Student_data = pd.merge(student_DatX, sxhool_Data, how="left", on=["school_name", "school_name"])

# %%
sxhool_Student_data.head(15)
# Out:
#     Student ID       student_name gender grade        school_name  \
# 0            0       Paul Bradley      M   9th  Huang High School
# 1            1       Victor Smith      M  12th  Huang High School
# 2            2    Kevin Rodriguez      M  12th  Huang High School
# 3            3  Dr. Richard Scott      M  12th  Huang High School
# 4            4         Bonnie Ray      F   9th  Huang High School
# 5            5      Bryan Miranda      M   9th  Huang High School
# 6            6      Sheena Carter      F  11th  Huang High School
# 7            7       Nicole Baker      F  12th  Huang High School
# 8            8       Michael Roth      M  10th  Huang High School
# 9            9     Matthew Greene      M  10th  Huang High School
# 10          10   Andrew Alexander      M  10th  Huang High School
# 11          11      Daniel Cooper      M  10th  Huang High School
# 12          12    Brittney Walker      F   9th  Huang High School
# 13          13       William Long      M   9th  Huang High School
# 14          14       Tammy Hebert      F  10th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget
# 0              66          79          0  District  2917  1910635
# 1              94          61          0  District  2917  1910635
# 2              90          60          0  District  2917  1910635
# 3              67          58          0  District  2917  1910635
# 4              97          84          0  District  2917  1910635
# 5              94          94          0  District  2917  1910635
# 6              82          80          0  District  2917  1910635
# 7              96          69          0  District  2917  1910635
# 8              95          87          0  District  2917  1910635
# 9              96          84          0  District  2917  1910635
# 10             90          70          0  District  2917  1910635
# 11             78          77          0  District  2917  1910635
# 12             64          79          0  District  2917  1910635
# 13             71          79          0  District  2917  1910635
# 14             85          67          0  District  2917  1910635

# %%
sxhool_Student_data.describe()
# Out:
#          Student ID  reading_score    math_score     School ID          size  \
# count  39170.000000    39170.00000  39170.000000  39170.000000  39170.000000
# mean   19584.500000       81.87784     78.985371      6.978172   3332.957110
# std    11307.549359       10.23958     12.309968      4.444329   1323.914069
# min        0.000000       63.00000     55.000000      0.000000    427.000000
# 25%     9792.250000       73.00000     69.000000      3.000000   1858.000000
# 50%    19584.500000       82.00000     79.000000      7.000000   2949.000000
# 75%    29376.750000       91.00000     89.000000     11.000000   4635.000000
# max    39169.000000       99.00000     99.000000     14.000000   4976.000000
#
#              budget
# count  3.917000e+04
# mean   2.117241e+06
# std    8.749987e+05
# min    2.480870e+05
# 25%    1.081356e+06
# 50%    1.910635e+06
# 75%    3.022020e+06
# max    3.124928e+06

# %%
sxhool_Student_data.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %% [markdown]
# District Summary
# Calculate the total number of schools
#
# Calculate the total number of students
#
# Calculate the total budget
#
# Calculate the average math score
#
# Calculate the average reading score
#
# Calculate the percentage of students with a passing math score (70 or greater)
#
# Calculate the percentage of students with a passing reading score (70 or greater)
#
# Calculate the percentage of students who passed math and reading (% Overall Passing)
#
# Create a dataframe to hold the above results
#
# Optional: give the displayed data cleaner formatting

# %%
# Calculate the total schools.

unique_school_name=sxhool_Student_data['school_name'].unique()

total_school=len(unique_school_name)

total_school
# Out:
# 15

# %%
# Calculate the total students.
total_students=sxhool_Student_data["student_name"].count()

total_students
# Out:
# 39170

# %%
# Calculate the total budget.
total_budget = sxhool_Data["budget"].sum()

total_budget
# Out:
# 24649428

# %%
# Calculate the average math score.
average_math_score = sxhool_Student_data["math_score"].mean()

average_math_score
# Out:
# 78.98537145774827

# %%
# Calculate the average reading score
average_reading_score = sxhool_Student_data["reading_score"].mean()

average_reading_score
# Out:
# 81.87784018381414

# %%
# percentage of students with a passing math score (70 < x )

students_passing_math = sxhool_Student_data.loc[sxhool_Student_data["math_score"] >= 70]
number_students_passing_math = students_passing_math["Student ID"].count()
percent_passing_math = (number_students_passing_math / total_students) * 100

percent_passing_math
# Out:
# 74.9808526933878

# %%
# percentage of students with a passing reading score (70 < x )
students_passing_reading = sxhool_Student_data.loc[sxhool_Student_data["reading_score"] >= 70]
number_students_passing_reading = students_passing_reading["Student ID"].count()
percent_passing_reading = (number_students_passing_reading / total_students) * 100

percent_passing_reading
# Out:
# 85.80546336482001

# %%
# Calculate the percentage of % Overall Passing
Overall_passing = sxhool_Student_data[(sxhool_Student_data['math_score'] >= 70) & (sxhool_Student_data['reading_score'] >= 70)]['Student ID'].count()/total_students*100
Overall_passing
# Out:
# 65.17232575950983

# %%
# Create a dataframe to hold the above results.
#code was develpted with by classmate M.R. and Tutor.

district_summary = pd.DataFrame({ "Total Schools": total_school, "Total Students": f"{total_students:,}", "Total Budget": f"${total_budget:,.2f}", "Average Reading Score": f"{average_reading_score:.2f}", "% Passing Math": f"{percent_passing_math:.2f}", "% Passing Reading": f"{percent_passing_reading:.2f}", "% Overall Passing": f"{Overall_passing: .2f}"}, index=[0])

district_summary
# Out:
#    Total Schools Total Students    Total Budget Average Reading Score  \
# 0             15         39,170  $24,649,428.00                 81.88
#
#   % Passing Math % Passing Reading % Overall Passing
# 0          74.98             85.81             65.17

# %%
# Group by school name
school_name = sxhool_Student_data.set_index('school_name').groupby(['school_name'])

# %%
# school types by school name
school_type = sxhool_Data.set_index('school_name')['type']

# %%
#  Calculate total students
total_student = school_name['Student ID'].count()

# %%
# Total school budget
total_school_budget = sxhool_Data.set_index('school_name')['budget']

# %%
# per student budget
budget_per_student = (sxhool_Data.set_index('school_name')['budget']/sxhool_Data.set_index('school_name')['size'])

# %%
# Average Math Score

average_math_score = school_name['math_score'].mean()

# %%
# Average Reading Score
average_reading_score = school_name['reading_score'].mean()

# %%
# % Passing Math

pass_math_percent = sxhool_Student_data[sxhool_Student_data['math_score'] >= 70].groupby('school_name')['Student ID'].count()/total_student*100

# %%
# % Passing Reading

pass_read_percent = sxhool_Student_data[sxhool_Student_data['reading_score'] >= 70].groupby('school_name')['Student ID'].count()/total_student*100

# %%
# % Overall Passing (The percentage of students that passed math and reading.

overall_pass = sxhool_Student_data[(sxhool_Student_data['reading_score'] >= 70) & (sxhool_Student_data['math_score'] >= 70)].groupby('school_name')['Student ID'].count()/total_student*100

# %%
school_summary = pd.DataFrame({"School Type": school_type, "Total Students": total_student, "Per Student Budget": budget_per_student, "Total School Budget": total_school_budget, "Average Math Score": average_math_score, "Average Reading Score": average_reading_score,'% Passing Math': pass_math_percent, '% Passing Reading': pass_read_percent,"% Overall Passing": overall_pass})

#munging
school_summary = school_summary[['School Type', 'Total Students', 'Total School Budget', 'Per Student Budget', 'Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading', '% Overall Passing']]


#formatting
school_summary.style.format({'Total Students': '{:}',"Total School Budget": "${:,.2f}", "Per Student Budget": "${:.2f}", 'Average Math Score': "{:2f}", 'Average Reading Score': "{:2f}", "% Passing Math": "{:2f}", "% Passing Reading": "{:2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_42e79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42e79_level0_col0" class="col_heading level0 col0" >School Type</th>
#       <th id="T_42e79_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_42e79_level0_col2" class="col_heading level0 col2" >Total School Budget</th>
#       <th id="T_42e79_level0_col3" class="col_heading level0 col3" >Per Student Budget</th>
#       <th id="T_42e79_level0_col4" class="col_heading level0 col4" >Average Math Score</th>
#       <th id="T_42e79_level0_col5" class="col_heading level0 col5" >Average Reading Score</th>
#       <th id="T_42e79_level0_col6" class="col_heading level0 col6" >% Passing Math</th>
#       <th id="T_42e79_level0_col7" class="col_heading level0 col7" >% Passing Reading</th>
#       <th id="T_42e79_level0_col8" class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42e79_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#       <td id="T_42e79_row0_col0" class="data row0 col0" >District</td>
#       <td id="T_42e79_row0_col1" class="data row0 col1" >4976</td>
#       <td id="T_42e79_row0_col2" class="data row0 col2" >$3,124,928.00</td>
#       <td id="T_42e79_row0_col3" class="data row0 col3" >$628.00</td>
#       <td id="T_42e79_row0_col4" class="data row0 col4" >77.048432</td>
#       <td id="T_42e79_row0_col5" class="data row0 col5" >81.033963</td>
#       <td id="T_42e79_row0_col6" class="data row0 col6" >66.680064</td>
#       <td id="T_42e79_row0_col7" class="data row0 col7" >81.933280</td>
#       <td id="T_42e79_row0_col8" class="data row0 col8" >54.642283</td>
#     </tr>
#     <tr>
#       <th id="T_42e79_level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#       <td id="T_42e79_row1_col0" class="data row1 col0" >Charter</td>
#       <td id="T_42e79_row1_col1" class="data row1 col1" >1858</td>
#       <td id="T_42e79_row1_col2" class="data row1 col2" >$1,081,356.00</td>
#       <td id="T_42e79_row1_col3" class="data row1 col3" >$582.00</td>
#       <td id="T_42e79_row1_col4" class="data row1 col4" >83.061895</td>
#       <td id="T_42e79_row1_col5" class="data row1 col5" >83.975780</td>
#       <td id="T_42e79_row1_col6" class="data row1 col6" >94.133477</td>
#       <td id="T_42e79_row1_col7" class="data row1 col7" >97.039828</td>
#       <td id="T_42e79_row1_col8" class="data row1 col8" >91.334769</td>
#     </tr>
#     <tr>
#       <th id="T_42e79_level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#       <td id="T_42e79_row2_col0" class="data row2 col0" >District</td>
#       <td id="T_42e79_row2_col1" class="data row2 col1" >2949</td>
#       <td id="T_42e79_row2_col2" class="data row2 col2" >$1,884,411.00</td>
#       <td id="T_42e79_row2_col3" class="data row2 col3" >$639.00</td>
#       <td id="T_42e79_row2_col4" class="data row2 col4" >76.711767</td>
#       <td id="T_42e79_row2_col5" class="data row2 col5" >81.158020</td>
#       <td id="T_42e79_row2_col6" class="data row2 col6" >65.988471</td>
#       <td id="T_42e79_row2_col7" class="data row2 col7" >80.739234</td>
#       <td id="T_42e79_row2_col8" class="data row2 col8" >53.204476</td>
#     </tr>
#     <tr>
#       <th id="T_42e79_level0_row3" class="row_heading level0 row3" >Ford High School</th>
#       <td id="T_42e79_row3_col0" class="data row3 col0" >District</td>
#       <td id="T_42e79_row3_col1" class="data row3 col1" >2739</td>
#       <td id="T_42e79_row3_col2" class="data row3 col2" >$1,763,916.00</td>
#       <td id="T_42e79_row3_col3" class="data row3 col3" >$644.00</td>
#       <td id="T_42e79_row3_col4" class="data row3 col4" >77.102592</td>
#       <td id="T_42e79_row3_col5" class="data row3 col5" >80.746258</td>
#       <td id="T_42e79_row3_col6" class="data row3 col6" >68.309602</td>
#       <td id="T_42e79_row3_col7" class="data row3 col7" >79.299014</td>
#       <td id="T_42e79_row3_col8" class="data row3 col8" >54.289887</td>
#     </tr>
#     <tr>
#       <th id="T_42e79_level0_row4" class="row_heading level0 row4" >Griffin High School</th>
#       <td id="T_42e79_row4_col0" class="data row4 col0" >Charter</td>
#       <td id="T_42e79_row4_col1" class="data row4 col1" >1468</td>
#       <td id="T_42e79_row4_col2" class="data row4 col2" >$917,500.00</td>
#       <td id="T_42e79_row4_col3" class="data row4 col3" >$625.00</td>
#       <td id="T_42e79_row4_col4" class="data row4 col4" >83.351499</td>
#       <td id="T_42e79_row4_col5" class="data row4 col5" >83.816757</td>
#       <td id="T_42e79_row4_col6" class="data row4 col6" >93.392371</td>
#       <td id="T_42e79_row4_col7" class="data row4 col7" >97.138965</td>
#       <td id="T_42e79_row4_col8" class="data row4 col8" >90.599455</td>
#     </tr>
#     <tr>
#       <th id="T_42e79_level0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#       <td id="T_42e79_row5_col0" class="data row5 col0" >District</td>
#       <td id="T_42e79_row5_col1" class="data row5 col1" >4635</td>
#       <td id="T_42e79_row5_col2" class="data row5 col2" >$3,022,020.00</td>
#       <td id="T_42e79_row5_col3" class="data row5 col3" >$652.00</td>
#       <td id="T_42e79_row5_col4" class="data row5 col4" >77.289752</td>
#       <td id="T_42e79_row5_col5" class="data row5 col5" >80.934412</td>
#       <td id="T_42e79_row5_col6" class="data row5 col6" >66.752967</td>
#       <td id="T_42e79_row5_col7" class="data row5 col7" >80.862999</td>
#       <td id="T_42e79_row5_col8" class="data row5 col8" >53.527508</td>
#     </tr>
#     <tr>
#       <th id="T_42e79_level0_row6" class="row_heading level0 row6" >Holden High School</th>
#       <td id="T_42e79_row6_col0" class="data row6 col0" >Charter</td>
#       <td id="T_42e79_row6_col1" class="data row6 col1" >427</td>
#       <td id="T_42e79_row6_col2" class="data row6 col2" >$248,087.00</td>
#       <td id="T_42e79_row6_col3" class="data row6 col3" >$581.00</td>
#       <td id="T_42e79_row6_col4" class="data row6 col4" >83.803279</td>
#       <td id="T_42e79_row6_col5" class="data row6 col5" >83.814988</td>
#       <td id="T_42e79_row6_col6" class="data row6 col6" >92.505855</td>
#       <td id="T_42e79_row6_col7" class="data row6 col7" >96.252927</td>
#       <td id="T_42e79_row6_col8" class="data row6 col8" >89.227166</td>
#     </tr>
#     <tr>
#       <th id="T_42e79_level0_row7" class="row_heading level0 row7" >Huang High School</th>
#       <td id="T_42e79_row7_col0" class="data row7 col0" >District</td>
#       <td id="T_42e79_row7_col1" class="data row7 col1" >2917</td>
#       <td id="T_42e79_row7_col2" class="data row7 col2" >$1,910,635.00</td>
#       <td id="T_42e79_row7_col3" class="data row7 col3" >$655.00</td>
#       <td id="T_42e79_row7_col4" class="data row7 col4" >76.629414</td>
#       <td id="T_42e79_row7_col5" class="data row7 col5" >81.182722</td>
#       <td id="T_42e79_row7_col6" class="data row7 col6" >65.683922</td>
#       <td id="T_42e79_row7_col7" class="data row7 col7" >81.316421</td>
#       <td id="T_42e79_row7_col8" class="data row7 col8" >53.513884</td>
#     </tr>
#     <tr>
#       <th id="T_42e79_level0_row8" class="row_heading level0 row8" >Johnson High School</th>
#       <td id="T_42e79_row8_col0" class="data row8 col0" >District</td>
#       <td id="T_42e79_row8_col1" class="data row8 col1" >4761</td>
#       <td id="T_42e79_row8_col2" class="data row8 col2" >$3,094,650.00</td>
#       <td id="T_42e79_row8_col3" class="data row8 col3" >$650.00</td>
#       <td id="T_42e79_row8_col4" class="data row8 col4" >77.072464</td>
#       <td id="T_42e79_row8_col5" class="data row8 col5" >80.966394</td>
#       <td id="T_42e7

# %% [markdown]
# # Top Performing Schools (By % Overall Passing)

# %%
# Sort and display the top five schools by passing rate 
top_perform = school_summary.sort_values("% Overall Passing", ascending = False)
top_perform.head().style.format({'Total Students': '{:}', "Total School Budget": "${:,.2f}", "Per Student Budget": "${:.2f}", "% Passing Math": "{:2f}", "% Passing Reading": "{:2f}", "% Overall Passing": "{:2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_417e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_417e0_level0_col0" class="col_heading level0 col0" >School Type</th>
#       <th id="T_417e0_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_417e0_level0_col2" class="col_heading level0 col2" >Total School Budget</th>
#       <th id="T_417e0_level0_col3" class="col_heading level0 col3" >Per Student Budget</th>
#       <th id="T_417e0_level0_col4" class="col_heading level0 col4" >Average Math Score</th>
#       <th id="T_417e0_level0_col5" class="col_heading level0 col5" >Average Reading Score</th>
#       <th id="T_417e0_level0_col6" class="col_heading level0 col6" >% Passing Math</th>
#       <th id="T_417e0_level0_col7" class="col_heading level0 col7" >% Passing Reading</th>
#       <th id="T_417e0_level0_col8" class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_417e0_level0_row0" class="row_heading level0 row0" >Cabrera High School</th>
#       <td id="T_417e0_row0_col0" class="data row0 col0" >Charter</td>
#       <td id="T_417e0_row0_col1" class="data row0 col1" >1858</td>
#       <td id="T_417e0_row0_col2" class="data row0 col2" >$1,081,356.00</td>
#       <td id="T_417e0_row0_col3" class="data row0 col3" >$582.00</td>
#       <td id="T_417e0_row0_col4" class="data row0 col4" >83.061895</td>
#       <td id="T_417e0_row0_col5" class="data row0 col5" >83.975780</td>
#       <td id="T_417e0_row0_col6" class="data row0 col6" >94.133477</td>
#       <td id="T_417e0_row0_col7" class="data row0 col7" >97.039828</td>
#       <td id="T_417e0_row0_col8" class="data row0 col8" >91.334769</td>
#     </tr>
#     <tr>
#       <th id="T_417e0_level0_row1" class="row_heading level0 row1" >Thomas High School</th>
#       <td id="T_417e0_row1_col0" class="data row1 col0" >Charter</td>
#       <td id="T_417e0_row1_col1" class="data row1 col1" >1635</td>
#       <td id="T_417e0_row1_col2" class="data row1 col2" >$1,043,130.00</td>
#       <td id="T_417e0_row1_col3" class="data row1 col3" >$638.00</td>
#       <td id="T_417e0_row1_col4" class="data row1 col4" >83.418349</td>
#       <td id="T_417e0_row1_col5" class="data row1 col5" >83.848930</td>
#       <td id="T_417e0_row1_col6" class="data row1 col6" >93.272171</td>
#       <td id="T_417e0_row1_col7" class="data row1 col7" >97.308869</td>
#       <td id="T_417e0_row1_col8" class="data row1 col8" >90.948012</td>
#     </tr>
#     <tr>
#       <th id="T_417e0_level0_row2" class="row_heading level0 row2" >Griffin High School</th>
#       <td id="T_417e0_row2_col0" class="data row2 col0" >Charter</td>
#       <td id="T_417e0_row2_col1" class="data row2 col1" >1468</td>
#       <td id="T_417e0_row2_col2" class="data row2 col2" >$917,500.00</td>
#       <td id="T_417e0_row2_col3" class="data row2 col3" >$625.00</td>
#       <td id="T_417e0_row2_col4" class="data row2 col4" >83.351499</td>
#       <td id="T_417e0_row2_col5" class="data row2 col5" >83.816757</td>
#       <td id="T_417e0_row2_col6" class="data row2 col6" >93.392371</td>
#       <td id="T_417e0_row2_col7" class="data row2 col7" >97.138965</td>
#       <td id="T_417e0_row2_col8" class="data row2 col8" >90.599455</td>
#     </tr>
#     <tr>
#       <th id="T_417e0_level0_row3" class="row_heading level0 row3" >Wilson High School</th>
#       <td id="T_417e0_row3_col0" class="data row3 col0" >Charter</td>
#       <td id="T_417e0_row3_col1" class="data row3 col1" >2283</td>
#       <td id="T_417e0_row3_col2" class="data row3 col2" >$1,319,574.00</td>
#       <td id="T_417e0_row3_col3" class="data row3 col3" >$578.00</td>
#       <td id="T_417e0_row3_col4" class="data row3 col4" >83.274201</td>
#       <td id="T_417e0_row3_col5" class="data row3 col5" >83.989488</td>
#       <td id="T_417e0_row3_col6" class="data row3 col6" >93.867718</td>
#       <td id="T_417e0_row3_col7" class="data row3 col7" >96.539641</td>
#       <td id="T_417e0_row3_col8" class="data row3 col8" >90.582567</td>
#     </tr>
#     <tr>
#       <th id="T_417e0_level0_row4" class="row_heading level0 row4" >Pena High School</th>
#       <td id="T_417e0_row4_col0" class="data row4 col0" >Charter</td>
#       <td id="T_417e0_row4_col1" class="data row4 col1" >962</td>
#       <td id="T_417e0_row4_col2" class="data row4 col2" >$585,858.00</td>
#       <td id="T_417e0_row4_col3" class="data row4 col3" >$609.00</td>
#       <td id="T_417e0_row4_col4" class="data row4 col4" >83.839917</td>
#       <td id="T_417e0_row4_col5" class="data row4 col5" >84.044699</td>
#       <td id="T_417e0_row4_col6" class="data row4 col6" >94.594595</td>
#       <td id="T_417e0_row4_col7" class="data row4 col7" >95.945946</td>
#       <td id="T_417e0_row4_col8" class="data row4 col8" >90.540541</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Bottom Performing Schools (By % Overall Passing)

# %%
# Sort and display the bottom five schools by passing rate 
bottom_perform = top_perform.tail(10)
bottom_perform = bottom_perform.sort_values('% Overall Passing')
bottom_perform.style.format({'Total Students': '{: }', "Total School Budget": "${:,.2f}", "Per Student Budget": "${:.2f}", "% Passing Reading": "{:2f}", "% Passing Math": "{:2f}", "% Overall Passing": "{:2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_397a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_397a0_level0_col0" class="col_heading level0 col0" >School Type</th>
#       <th id="T_397a0_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_397a0_level0_col2" class="col_heading level0 col2" >Total School Budget</th>
#       <th id="T_397a0_level0_col3" class="col_heading level0 col3" >Per Student Budget</th>
#       <th id="T_397a0_level0_col4" class="col_heading level0 col4" >Average Math Score</th>
#       <th id="T_397a0_level0_col5" class="col_heading level0 col5" >Average Reading Score</th>
#       <th id="T_397a0_level0_col6" class="col_heading level0 col6" >% Passing Math</th>
#       <th id="T_397a0_level0_col7" class="col_heading level0 col7" >% Passing Reading</th>
#       <th id="T_397a0_level0_col8" class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_397a0_level0_row0" class="row_heading level0 row0" >Rodriguez High School</th>
#       <td id="T_397a0_row0_col0" class="data row0 col0" >District</td>
#       <td id="T_397a0_row0_col1" class="data row0 col1" > 3999</td>
#       <td id="T_397a0_row0_col2" class="data row0 col2" >$2,547,363.00</td>
#       <td id="T_397a0_row0_col3" class="data row0 col3" >$637.00</td>
#       <td id="T_397a0_row0_col4" class="data row0 col4" >76.842711</td>
#       <td id="T_397a0_row0_col5" class="data row0 col5" >80.744686</td>
#       <td id="T_397a0_row0_col6" class="data row0 col6" >66.366592</td>
#       <td id="T_397a0_row0_col7" class="data row0 col7" >80.220055</td>
#       <td id="T_397a0_row0_col8" class="data row0 col8" >52.988247</td>
#     </tr>
#     <tr>
#       <th id="T_397a0_level0_row1" class="row_heading level0 row1" >Figueroa High School</th>
#       <td id="T_397a0_row1_col0" class="data row1 col0" >District</td>
#       <td id="T_397a0_row1_col1" class="data row1 col1" > 2949</td>
#       <td id="T_397a0_row1_col2" class="data row1 col2" >$1,884,411.00</td>
#       <td id="T_397a0_row1_col3" class="data row1 col3" >$639.00</td>
#       <td id="T_397a0_row1_col4" class="data row1 col4" >76.711767</td>
#       <td id="T_397a0_row1_col5" class="data row1 col5" >81.158020</td>
#       <td id="T_397a0_row1_col6" class="data row1 col6" >65.988471</td>
#       <td id="T_397a0_row1_col7" class="data row1 col7" >80.739234</td>
#       <td id="T_397a0_row1_col8" class="data row1 col8" >53.204476</td>
#     </tr>
#     <tr>
#       <th id="T_397a0_level0_row2" class="row_heading level0 row2" >Huang High School</th>
#       <td id="T_397a0_row2_col0" class="data row2 col0" >District</td>
#       <td id="T_397a0_row2_col1" class="data row2 col1" > 2917</td>
#       <td id="T_397a0_row2_col2" class="data row2 col2" >$1,910,635.00</td>
#       <td id="T_397a0_row2_col3" class="data row2 col3" >$655.00</td>
#       <td id="T_397a0_row2_col4" class="data row2 col4" >76.629414</td>
#       <td id="T_397a0_row2_col5" class="data row2 col5" >81.182722</td>
#       <td id="T_397a0_row2_col6" class="data row2 col6" >65.683922</td>
#       <td id="T_397a0_row2_col7" class="data row2 col7" >81.316421</td>
#       <td id="T_397a0_row2_col8" class="data row2 col8" >53.513884</td>
#     </tr>
#     <tr>
#       <th id="T_397a0_level0_row3" class="row_heading level0 row3" >Hernandez High School</th>
#       <td id="T_397a0_row3_col0" class="data row3 col0" >District</td>
#       <td id="T_397a0_row3_col1" class="data row3 col1" > 4635</td>
#       <td id="T_397a0_row3_col2" class="data row3 col2" >$3,022,020.00</td>
#       <td id="T_397a0_row3_col3" class="data row3 col3" >$652.00</td>
#       <td id="T_397a0_row3_col4" class="data row3 col4" >77.289752</td>
#       <td id="T_397a0_row3_col5" class="data row3 col5" >80.934412</td>
#       <td id="T_397a0_row3_col6" class="data row3 col6" >66.752967</td>
#       <td id="T_397a0_row3_col7" class="data row3 col7" >80.862999</td>
#       <td id="T_397a0_row3_col8" class="data row3 col8" >53.527508</td>
#     </tr>
#     <tr>
#       <th id="T_397a0_level0_row4" class="row_heading level0 row4" >Johnson High School</th>
#       <td id="T_397a0_row4_col0" class="data row4 col0" >District</td>
#       <td id="T_397a0_row4_col1" class="data row4 col1" > 4761</td>
#       <td id="T_397a0_row4_col2" class="data row4 col2" >$3,094,650.00</td>
#       <td id="T_397a0_row4_col3" class="data row4 col3" >$650.00</td>
#       <td id="T_397a0_row4_col4" class="data row4 col4" >77.072464</td>
#       <td id="T_397a0_row4_col5" class="data row4 col5" >80.966394</td>
#       <td id="T_397a0_row4_col6" class="data row4 col6" >66.057551</td>
#       <td id="T_397a0_row4_col7" class="data row4 col7" >81.222432</td>
#       <td id="T_397a0_row4_col8" class="data row4 col8" >53.539172</td>
#     </tr>
#     <tr>
#       <th id="T_397a0_level0_row5" class="row_heading level0 row5" >Ford High School</th>
#       <td id="T_397a0_row5_col0" class="data row5 col0" >District</td>
#       <td id="T_397a0_row5_col1" class="data row5 col1" > 2739</td>
#       <td id="T_397a0_row5_col2" class="data row5 col2" >$1,763,916.00</td>
#       <td id="T_397a0_row5_col3" class="data row5 col3" >$644.00</td>
#       <td id="T_397a0_row5_col4" class="data row5 col4" >77.102592</td>
#       <td id="T_397a0_row5_col5" class="data row5 col5" >80.746258</td>
#       <td id="T_397a0_row5_col6" class="data row5 col6" >68.309602</td>
#       <td id="T_397a0_row5_col7" class="data row5 col7" >79.299014</td>
#       <td id="T_397a0_row5_col8" class="data row5 col8" >54.289887</td>
#     </tr>
#     <tr>
#       <th id="T_397a0_level0_row6" class="row_heading level0 row6" >Bailey High School</th>
#       <td id="T_397a0_row6_col0" class="data row6 col0" >District</td>
#       <td id="T_397a0_row6_col1" class="data row6 col1" > 4976</td>
#       <td id="T_397a0_row6_col2" class="data row6 col2" >$3,124,928.00</td>
#       <td id="T_397a0_row6_col3" class="data row6 col3" >$628.00</td>
#       <td id="T_397a0_row6_col4" class="data row6 col4" >77.048432</td>
#       <td id="T_397a0_row6_col5" class="data row6 col5" >81.033963</td>
#       <td id="T_397a0_row6_col6" class="data row6 col6" >66.680064</td>
#       <td id="T_397a0_row6_col7" class="data row6 col7" >81.933280</td>
#       <td id="T_397a0_row6_col8" class="data row6 col8" >54.642283</td>
#     </tr>
#     <tr>
#       <th id="T_397a0_level0_row7" class="row_heading level0 row7" >Holden High School</th>
#       <td id="T_397a0_row7_col0" class="data row7 col0" >Charter</td>
#       <td id="T_397a0_row7_col1" class="data row7 col1" > 427</td>
#       <td id="T_397a0_row7_col2" class="data row7 col2" >$248,087.00</td>
#       <td id="T_397a0_row7_col3" class="data row7 col3" >$581.00</td>
#       <td id="T_397a0_row7_col4" class="data row7 col4" >83.803279</td>
#       <td id="T_397a0_row7_col5" class="data row7 col5" >83.814988</td>
#       <td id="T_397a0_row7_col6" class="data row7 col6" >92.505855</td>
#       <td id="T_397a0_row7_col7" class="data row7 col7" >96.252927</td>
#       <td id="T_397a0_row7_col8" class="data row7 col8" >89.227166</td>
#     </tr>
#     <tr>
#       <th id="T_397a0_level0_row8" class="row_heading level0 row8" >Shelton High School</th>
#       <td id="T_397a0_row8_col0" class="data row8 col0" >Charter</td>
#       <td id="T_397a0_row8_col1" class="data row8 col1" > 1761</td>
#       <td id="T_397a0_row8_col2" class="data row8 col2" >$1,056,600.00</td>
#       <td id="T_397a0_row8_col3" class="data row8 col3" >$600.00</td>
#       <td id="T_397a0_row8_col4" class="data row8 col4" >83.359455</td>
#       <td id="T_397a0_row8_col5" class="data row8 col5" >83.725724</td>

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Average Reading Score
average_reading_score = school_name['reading_score'].mean()

# %%
# % Passing Math

pass_math_percent = sxhool_Student_data[sxhool_Student_data['math_score'] >= 70].groupby('school_name')['Student ID'].count()/total_student*100

# %%
# % Passing Reading

pass_read_percent = sxhool_Student_data[sxhool_Student_data['reading_score'] >= 70].groupby('school_name')['Student ID'].count()/total_student*100

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Sort and display the top five schools by passing rate 
top_perform = school_summary.sort_values("% Overall Passing", ascending = False)
top_perform.head().style.format({'Total Students': '{:}', "Total School Budget": "${:,.2f}", "Per Student Budget": "${:.2f}",  "% Passing Math": "{:2f}", "% Passing Reading": "{:2f}", "% Overall Passing": "{:2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_6915b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6915b_level0_col0" class="col_heading level0 col0" >School Type</th>
#       <th id="T_6915b_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_6915b_level0_col2" class="col_heading level0 col2" >Total School Budget</th>
#       <th id="T_6915b_level0_col3" class="col_heading level0 col3" >Per Student Budget</th>
#       <th id="T_6915b_level0_col4" class="col_heading level0 col4" >Average Math Score</th>
#       <th id="T_6915b_level0_col5" class="col_heading level0 col5" >Average Reading Score</th>
#       <th id="T_6915b_level0_col6" class="col_heading level0 col6" >% Passing Math</th>
#       <th id="T_6915b_level0_col7" class="col_heading level0 col7" >% Passing Reading</th>
#       <th id="T_6915b_level0_col8" class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6915b_level0_row0" class="row_heading level0 row0" >Cabrera High School</th>
#       <td id="T_6915b_row0_col0" class="data row0 col0" >Charter</td>
#       <td id="T_6915b_row0_col1" class="data row0 col1" >1858</td>
#       <td id="T_6915b_row0_col2" class="data row0 col2" >$1,081,356.00</td>
#       <td id="T_6915b_row0_col3" class="data row0 col3" >$582.00</td>
#       <td id="T_6915b_row0_col4" class="data row0 col4" >83.061895</td>
#       <td id="T_6915b_row0_col5" class="data row0 col5" >83.975780</td>
#       <td id="T_6915b_row0_col6" class="data row0 col6" >94.133477</td>
#       <td id="T_6915b_row0_col7" class="data row0 col7" >97.039828</td>
#       <td id="T_6915b_row0_col8" class="data row0 col8" >91.334769</td>
#     </tr>
#     <tr>
#       <th id="T_6915b_level0_row1" class="row_heading level0 row1" >Thomas High School</th>
#       <td id="T_6915b_row1_col0" class="data row1 col0" >Charter</td>
#       <td id="T_6915b_row1_col1" class="data row1 col1" >1635</td>
#       <td id="T_6915b_row1_col2" class="data row1 col2" >$1,043,130.00</td>
#       <td id="T_6915b_row1_col3" class="data row1 col3" >$638.00</td>
#       <td id="T_6915b_row1_col4" class="data row1 col4" >83.418349</td>
#       <td id="T_6915b_row1_col5" class="data row1 col5" >83.848930</td>
#       <td id="T_6915b_row1_col6" class="data row1 col6" >93.272171</td>
#       <td id="T_6915b_row1_col7" class="data row1 col7" >97.308869</td>
#       <td id="T_6915b_row1_col8" class="data row1 col8" >90.948012</td>
#     </tr>
#     <tr>
#       <th id="T_6915b_level0_row2" class="row_heading level0 row2" >Griffin High School</th>
#       <td id="T_6915b_row2_col0" class="data row2 col0" >Charter</td>
#       <td id="T_6915b_row2_col1" class="data row2 col1" >1468</td>
#       <td id="T_6915b_row2_col2" class="data row2 col2" >$917,500.00</td>
#       <td id="T_6915b_row2_col3" class="data row2 col3" >$625.00</td>
#       <td id="T_6915b_row2_col4" class="data row2 col4" >83.351499</td>
#       <td id="T_6915b_row2_col5" class="data row2 col5" >83.816757</td>
#       <td id="T_6915b_row2_col6" class="data row2 col6" >93.392371</td>
#       <td id="T_6915b_row2_col7" class="data row2 col7" >97.138965</td>
#       <td id="T_6915b_row2_col8" class="data row2 col8" >90.599455</td>
#     </tr>
#     <tr>
#       <th id="T_6915b_level0_row3" class="row_heading level0 row3" >Wilson High School</th>
#       <td id="T_6915b_row3_col0" class="data row3 col0" >Charter</td>
#       <td id="T_6915b_row3_col1" class="data row3 col1" >2283</td>
#       <td id="T_6915b_row3_col2" class="data row3 col2" >$1,319,574.00</td>
#       <td id="T_6915b_row3_col3" class="data row3 col3" >$578.00</td>
#       <td id="T_6915b_row3_col4" class="data row3 col4" >83.274201</td>
#       <td id="T_6915b_row3_col5" class="data row3 col5" >83.989488</td>
#       <td id="T_6915b_row3_col6" class="data row3 col6" >93.867718</td>
#       <td id="T_6915b_row3_col7" class="data row3 col7" >96.539641</td>
#       <td id="T_6915b_row3_col8" class="data row3 col8" >90.582567</td>
#     </tr>
#     <tr>
#       <th id="T_6915b_level0_row4" class="row_heading level0 row4" >Pena High School</th>
#       <td id="T_6915b_row4_col0" class="data row4 col0" >Charter</td>
#       <td id="T_6915b_row4_col1" class="data row4 col1" >962</td>
#       <td id="T_6915b_row4_col2" class="data row4 col2" >$585,858.00</td>
#       <td id="T_6915b_row4_col3" class="data row4 col3" >$609.00</td>
#       <td id="T_6915b_row4_col4" class="data row4 col4" >83.839917</td>
#       <td id="T_6915b_row4_col5" class="data row4 col5" >84.044699</td>
#       <td id="T_6915b_row4_col6" class="data row4 col6" >94.594595</td>
#       <td id="T_6915b_row4_col7" class="data row4 col7" >95.945946</td>
#       <td id="T_6915b_row4_col8" class="data row4 col8" >90.540541</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
# Sort and display the bottom five schools by passing rate 
bottom_perform = top_perform.tail(10)
bottom_perform = bottom_perform.sort_values('% Overall Passing')
bottom_perform.style.format({'Total Students': '{: }', "Total School Budget": "${:,.2f}", "Per Student Budget": "${:.2f}", "% Passing Math": "{:2f}", "% Passing Reading": "{:2f}", "% Overall Passing": "{:2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_84e71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84e71_level0_col0" class="col_heading level0 col0" >School Type</th>
#       <th id="T_84e71_level0_col1" class="col_heading level0 col1" >Total Students</th>
#       <th id="T_84e71_level0_col2" class="col_heading level0 col2" >Total School Budget</th>
#       <th id="T_84e71_level0_col3" class="col_heading level0 col3" >Per Student Budget</th>
#       <th id="T_84e71_level0_col4" class="col_heading level0 col4" >Average Math Score</th>
#       <th id="T_84e71_level0_col5" class="col_heading level0 col5" >Average Reading Score</th>
#       <th id="T_84e71_level0_col6" class="col_heading level0 col6" >% Passing Math</th>
#       <th id="T_84e71_level0_col7" class="col_heading level0 col7" >% Passing Reading</th>
#       <th id="T_84e71_level0_col8" class="col_heading level0 col8" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >school_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84e71_level0_row0" class="row_heading level0 row0" >Rodriguez High School</th>
#       <td id="T_84e71_row0_col0" class="data row0 col0" >District</td>
#       <td id="T_84e71_row0_col1" class="data row0 col1" > 3999</td>
#       <td id="T_84e71_row0_col2" class="data row0 col2" >$2,547,363.00</td>
#       <td id="T_84e71_row0_col3" class="data row0 col3" >$637.00</td>
#       <td id="T_84e71_row0_col4" class="data row0 col4" >76.842711</td>
#       <td id="T_84e71_row0_col5" class="data row0 col5" >80.744686</td>
#       <td id="T_84e71_row0_col6" class="data row0 col6" >66.366592</td>
#       <td id="T_84e71_row0_col7" class="data row0 col7" >80.220055</td>
#       <td id="T_84e71_row0_col8" class="data row0 col8" >52.988247</td>
#     </tr>
#     <tr>
#       <th id="T_84e71_level0_row1" class="row_heading level0 row1" >Figueroa High School</th>
#       <td id="T_84e71_row1_col0" class="data row1 col0" >District</td>
#       <td id="T_84e71_row1_col1" class="data row1 col1" > 2949</td>
#       <td id="T_84e71_row1_col2" class="data row1 col2" >$1,884,411.00</td>
#       <td id="T_84e71_row1_col3" class="data row1 col3" >$639.00</td>
#       <td id="T_84e71_row1_col4" class="data row1 col4" >76.711767</td>
#       <td id="T_84e71_row1_col5" class="data row1 col5" >81.158020</td>
#       <td id="T_84e71_row1_col6" class="data row1 col6" >65.988471</td>
#       <td id="T_84e71_row1_col7" class="data row1 col7" >80.739234</td>
#       <td id="T_84e71_row1_col8" class="data row1 col8" >53.204476</td>
#     </tr>
#     <tr>
#       <th id="T_84e71_level0_row2" class="row_heading level0 row2" >Huang High School</th>
#       <td id="T_84e71_row2_col0" class="data row2 col0" >District</td>
#       <td id="T_84e71_row2_col1" class="data row2 col1" > 2917</td>
#       <td id="T_84e71_row2_col2" class="data row2 col2" >$1,910,635.00</td>
#       <td id="T_84e71_row2_col3" class="data row2 col3" >$655.00</td>
#       <td id="T_84e71_row2_col4" class="data row2 col4" >76.629414</td>
#       <td id="T_84e71_row2_col5" class="data row2 col5" >81.182722</td>
#       <td id="T_84e71_row2_col6" class="data row2 col6" >65.683922</td>
#       <td id="T_84e71_row2_col7" class="data row2 col7" >81.316421</td>
#       <td id="T_84e71_row2_col8" class="data row2 col8" >53.513884</td>
#     </tr>
#     <tr>
#       <th id="T_84e71_level0_row3" class="row_heading level0 row3" >Hernandez High School</th>
#       <td id="T_84e71_row3_col0" class="data row3 col0" >District</td>
#       <td id="T_84e71_row3_col1" class="data row3 col1" > 4635</td>
#       <td id="T_84e71_row3_col2" class="data row3 col2" >$3,022,020.00</td>
#       <td id="T_84e71_row3_col3" class="data row3 col3" >$652.00</td>
#       <td id="T_84e71_row3_col4" class="data row3 col4" >77.289752</td>
#       <td id="T_84e71_row3_col5" class="data row3 col5" >80.934412</td>
#       <td id="T_84e71_row3_col6" class="data row3 col6" >66.752967</td>
#       <td id="T_84e71_row3_col7" class="data row3 col7" >80.862999</td>
#       <td id="T_84e71_row3_col8" class="data row3 col8" >53.527508</td>
#     </tr>
#     <tr>
#       <th id="T_84e71_level0_row4" class="row_heading level0 row4" >Johnson High School</th>
#       <td id="T_84e71_row4_col0" class="data row4 col0" >District</td>
#       <td id="T_84e71_row4_col1" class="data row4 col1" > 4761</td>
#       <td id="T_84e71_row4_col2" class="data row4 col2" >$3,094,650.00</td>
#       <td id="T_84e71_row4_col3" class="data row4 col3" >$650.00</td>
#       <td id="T_84e71_row4_col4" class="data row4 col4" >77.072464</td>
#       <td id="T_84e71_row4_col5" class="data row4 col5" >80.966394</td>
#       <td id="T_84e71_row4_col6" class="data row4 col6" >66.057551</td>
#       <td id="T_84e71_row4_col7" class="data row4 col7" >81.222432</td>
#       <td id="T_84e71_row4_col8" class="data row4 col8" >53.539172</td>
#     </tr>
#     <tr>
#       <th id="T_84e71_level0_row5" class="row_heading level0 row5" >Ford High School</th>
#       <td id="T_84e71_row5_col0" class="data row5 col0" >District</td>
#       <td id="T_84e71_row5_col1" class="data row5 col1" > 2739</td>
#       <td id="T_84e71_row5_col2" class="data row5 col2" >$1,763,916.00</td>
#       <td id="T_84e71_row5_col3" class="data row5 col3" >$644.00</td>
#       <td id="T_84e71_row5_col4" class="data row5 col4" >77.102592</td>
#       <td id="T_84e71_row5_col5" class="data row5 col5" >80.746258</td>
#       <td id="T_84e71_row5_col6" class="data row5 col6" >68.309602</td>
#       <td id="T_84e71_row5_col7" class="data row5 col7" >79.299014</td>
#       <td id="T_84e71_row5_col8" class="data row5 col8" >54.289887</td>
#     </tr>
#     <tr>
#       <th id="T_84e71_level0_row6" class="row_heading level0 row6" >Bailey High School</th>
#       <td id="T_84e71_row6_col0" class="data row6 col0" >District</td>
#       <td id="T_84e71_row6_col1" class="data row6 col1" > 4976</td>
#       <td id="T_84e71_row6_col2" class="data row6 col2" >$3,124,928.00</td>
#       <td id="T_84e71_row6_col3" class="data row6 col3" >$628.00</td>
#       <td id="T_84e71_row6_col4" class="data row6 col4" >77.048432</td>
#       <td id="T_84e71_row6_col5" class="data row6 col5" >81.033963</td>
#       <td id="T_84e71_row6_col6" class="data row6 col6" >66.680064</td>
#       <td id="T_84e71_row6_col7" class="data row6 col7" >81.933280</td>
#       <td id="T_84e71_row6_col8" class="data row6 col8" >54.642283</td>
#     </tr>
#     <tr>
#       <th id="T_84e71_level0_row7" class="row_heading level0 row7" >Holden High School</th>
#       <td id="T_84e71_row7_col0" class="data row7 col0" >Charter</td>
#       <td id="T_84e71_row7_col1" class="data row7 col1" > 427</td>
#       <td id="T_84e71_row7_col2" class="data row7 col2" >$248,087.00</td>
#       <td id="T_84e71_row7_col3" class="data row7 col3" >$581.00</td>
#       <td id="T_84e71_row7_col4" class="data row7 col4" >83.803279</td>
#       <td id="T_84e71_row7_col5" class="data row7 col5" >83.814988</td>
#       <td id="T_84e71_row7_col6" class="data row7 col6" >92.505855</td>
#       <td id="T_84e71_row7_col7" class="data row7 col7" >96.252927</td>
#       <td id="T_84e71_row7_col8" class="data row7 col8" >89.227166</td>
#     </tr>
#     <tr>
#       <th id="T_84e71_level0_row8" class="row_heading level0 row8" >Shelton High School</th>
#       <td id="T_84e71_row8_col0" class="data row8 col0" >Charter</td>
#       <td id="T_84e71_row8_col1" class="data row8 col1" > 1761</td>
#       <td id="T_84e71_row8_col2" class="data row8 col2" >$1,056,600.00</td>
#       <td id="T_84e71_row8_col3" class="data row8 col3" >$600.00</td>
#       <td id="T_84e71_row8_col4" class="data row8 col4" >83.359455</td>
#       <td id="T_84e71_row8_col5" class="data row8 col5" >83.725724</td>

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#creates grade level average math scores for each school 
ninth_math = student_DatX.loc[student_DatX['grade'] == '9th'].groupby('school_name')["math_score"].mean()
tenth_math = student_DatX.loc[student_DatX['grade'] == '10th'].groupby('school_name')["math_score"].mean()
eleventh_math = student_DatX.loc[student_DatX['grade'] == '11th'].groupby('school_name')["math_score"].mean()
twelfth_math = student_DatX.loc[student_DatX['grade'] == '12th'].groupby('school_name')["math_score"].mean()

math_scores = pd.DataFrame({ "9th": ninth_math, "10th": tenth_math, "11th": eleventh_math, "12th": twelfth_math})

math_scores = math_scores[['9th', '10th', '11th', '12th']]
math_scores.index.name = "School Name"

#show and format
math_scores.style.format({ '9th': '{:.2f}', "10th": '{:.2f}', "11th": "{:.2f}", "12th": "{:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_67b8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67b8c_level0_col0" class="col_heading level0 col0" >9th</th>
#       <th id="T_67b8c_level0_col1" class="col_heading level0 col1" >10th</th>
#       <th id="T_67b8c_level0_col2" class="col_heading level0 col2" >11th</th>
#       <th id="T_67b8c_level0_col3" class="col_heading level0 col3" >12th</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >School Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67b8c_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#       <td id="T_67b8c_row0_col0" class="data row0 col0" >77.08</td>
#       <td id="T_67b8c_row0_col1" class="data row0 col1" >77.00</td>
#       <td id="T_67b8c_row0_col2" class="data row0 col2" >77.52</td>
#       <td id="T_67b8c_row0_col3" class="data row0 col3" >76.49</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#       <td id="T_67b8c_row1_col0" class="data row1 col0" >83.09</td>
#       <td id="T_67b8c_row1_col1" class="data row1 col1" >83.15</td>
#       <td id="T_67b8c_row1_col2" class="data row1 col2" >82.77</td>
#       <td id="T_67b8c_row1_col3" class="data row1 col3" >83.28</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#       <td id="T_67b8c_row2_col0" class="data row2 col0" >76.40</td>
#       <td id="T_67b8c_row2_col1" class="data row2 col1" >76.54</td>
#       <td id="T_67b8c_row2_col2" class="data row2 col2" >76.88</td>
#       <td id="T_67b8c_row2_col3" class="data row2 col3" >77.15</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row3" class="row_heading level0 row3" >Ford High School</th>
#       <td id="T_67b8c_row3_col0" class="data row3 col0" >77.36</td>
#       <td id="T_67b8c_row3_col1" class="data row3 col1" >77.67</td>
#       <td id="T_67b8c_row3_col2" class="data row3 col2" >76.92</td>
#       <td id="T_67b8c_row3_col3" class="data row3 col3" >76.18</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row4" class="row_heading level0 row4" >Griffin High School</th>
#       <td id="T_67b8c_row4_col0" class="data row4 col0" >82.04</td>
#       <td id="T_67b8c_row4_col1" class="data row4 col1" >84.23</td>
#       <td id="T_67b8c_row4_col2" class="data row4 col2" >83.84</td>
#       <td id="T_67b8c_row4_col3" class="data row4 col3" >83.36</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#       <td id="T_67b8c_row5_col0" class="data row5 col0" >77.44</td>
#       <td id="T_67b8c_row5_col1" class="data row5 col1" >77.34</td>
#       <td id="T_67b8c_row5_col2" class="data row5 col2" >77.14</td>
#       <td id="T_67b8c_row5_col3" class="data row5 col3" >77.19</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row6" class="row_heading level0 row6" >Holden High School</th>
#       <td id="T_67b8c_row6_col0" class="data row6 col0" >83.79</td>
#       <td id="T_67b8c_row6_col1" class="data row6 col1" >83.43</td>
#       <td id="T_67b8c_row6_col2" class="data row6 col2" >85.00</td>
#       <td id="T_67b8c_row6_col3" class="data row6 col3" >82.86</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row7" class="row_heading level0 row7" >Huang High School</th>
#       <td id="T_67b8c_row7_col0" class="data row7 col0" >77.03</td>
#       <td id="T_67b8c_row7_col1" class="data row7 col1" >75.91</td>
#       <td id="T_67b8c_row7_col2" class="data row7 col2" >76.45</td>
#       <td id="T_67b8c_row7_col3" class="data row7 col3" >77.23</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row8" class="row_heading level0 row8" >Johnson High School</th>
#       <td id="T_67b8c_row8_col0" class="data row8 col0" >77.19</td>
#       <td id="T_67b8c_row8_col1" class="data row8 col1" >76.69</td>
#       <td id="T_67b8c_row8_col2" class="data row8 col2" >77.49</td>
#       <td id="T_67b8c_row8_col3" class="data row8 col3" >76.86</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row9" class="row_heading level0 row9" >Pena High School</th>
#       <td id="T_67b8c_row9_col0" class="data row9 col0" >83.63</td>
#       <td id="T_67b8c_row9_col1" class="data row9 col1" >83.37</td>
#       <td id="T_67b8c_row9_col2" class="data row9 col2" >84.33</td>
#       <td id="T_67b8c_row9_col3" class="data row9 col3" >84.12</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row10" class="row_heading level0 row10" >Rodriguez High School</th>
#       <td id="T_67b8c_row10_col0" class="data row10 col0" >76.86</td>
#       <td id="T_67b8c_row10_col1" class="data row10 col1" >76.61</td>
#       <td id="T_67b8c_row10_col2" class="data row10 col2" >76.40</td>
#       <td id="T_67b8c_row10_col3" class="data row10 col3" >77.69</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row11" class="row_heading level0 row11" >Shelton High School</th>
#       <td id="T_67b8c_row11_col0" class="data row11 col0" >83.42</td>
#       <td id="T_67b8c_row11_col1" class="data row11 col1" >82.92</td>
#       <td id="T_67b8c_row11_col2" class="data row11 col2" >83.38</td>
#       <td id="T_67b8c_row11_col3" class="data row11 col3" >83.78</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row12" class="row_heading level0 row12" >Thomas High School</th>
#       <td id="T_67b8c_row12_col0" class="data row12 col0" >83.59</td>
#       <td id="T_67b8c_row12_col1" class="data row12 col1" >83.09</td>
#       <td id="T_67b8c_row12_col2" class="data row12 col2" >83.50</td>
#       <td id="T_67b8c_row12_col3" class="data row12 col3" >83.50</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row13" class="row_heading level0 row13" >Wilson High School</th>
#       <td id="T_67b8c_row13_col0" class="data row13 col0" >83.09</td>
#       <td id="T_67b8c_row13_col1" class="data row13 col1" >83.72</td>
#       <td id="T_67b8c_row13_col2" class="data row13 col2" >83.20</td>
#       <td id="T_67b8c_row13_col3" class="data row13 col3" >83.04</td>
#     </tr>
#     <tr>
#       <th id="T_67b8c_level0_row14" class="row_heading level0 row14" >Wright High School</th>
#       <td id="T_67b8c_row14_col0" class="data row14 col0" >83.26</td>
#       <td id="T_67b8c_row14_col1" class="data row14 col1" >84.01</td>
#       <td id="T_67b8c_row14_col2" class="data row14 col2" >83.84</td>
#       <td id="T_67b8c_row14_col3" class="data row14 col3" >83.64</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#creates grade level average reading scores for each school
ninth_reading = student_DatX.loc[student_DatX['grade'] == '9th'].groupby('school_name')["reading_score"].mean()
tenth_reading = student_DatX.loc[student_DatX['grade'] == '10th'].groupby('school_name')["reading_score"].mean()
eleventh_reading = student_DatX.loc[student_DatX['grade'] == '11th'].groupby('school_name')["reading_score"].mean()
twelfth_reading = student_DatX.loc[student_DatX['grade'] == '12th'].groupby('school_name')["reading_score"].mean()

#merges the reading score averages by school and grade together
reading_scores = pd.DataFrame({"9th": ninth_reading, "10th": tenth_reading, "11th": eleventh_reading, "12th": twelfth_reading})

reading_scores = reading_scores[['9th', '10th', '11th', '12th']]
reading_scores.index.name = "School Name"

#format
reading_scores.style.format({'9th': '{:.2f}', "10th": '{:.2f}', "11th": "{:.2f}", "12th": "{:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_8f8e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f8e7_level0_col0" class="col_heading level0 col0" >9th</th>
#       <th id="T_8f8e7_level0_col1" class="col_heading level0 col1" >10th</th>
#       <th id="T_8f8e7_level0_col2" class="col_heading level0 col2" >11th</th>
#       <th id="T_8f8e7_level0_col3" class="col_heading level0 col3" >12th</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >School Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f8e7_level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#       <td id="T_8f8e7_row0_col0" class="data row0 col0" >81.30</td>
#       <td id="T_8f8e7_row0_col1" class="data row0 col1" >80.91</td>
#       <td id="T_8f8e7_row0_col2" class="data row0 col2" >80.95</td>
#       <td id="T_8f8e7_row0_col3" class="data row0 col3" >80.91</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#       <td id="T_8f8e7_row1_col0" class="data row1 col0" >83.68</td>
#       <td id="T_8f8e7_row1_col1" class="data row1 col1" >84.25</td>
#       <td id="T_8f8e7_row1_col2" class="data row1 col2" >83.79</td>
#       <td id="T_8f8e7_row1_col3" class="data row1 col3" >84.29</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#       <td id="T_8f8e7_row2_col0" class="data row2 col0" >81.20</td>
#       <td id="T_8f8e7_row2_col1" class="data row2 col1" >81.41</td>
#       <td id="T_8f8e7_row2_col2" class="data row2 col2" >80.64</td>
#       <td id="T_8f8e7_row2_col3" class="data row2 col3" >81.38</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row3" class="row_heading level0 row3" >Ford High School</th>
#       <td id="T_8f8e7_row3_col0" class="data row3 col0" >80.63</td>
#       <td id="T_8f8e7_row3_col1" class="data row3 col1" >81.26</td>
#       <td id="T_8f8e7_row3_col2" class="data row3 col2" >80.40</td>
#       <td id="T_8f8e7_row3_col3" class="data row3 col3" >80.66</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row4" class="row_heading level0 row4" >Griffin High School</th>
#       <td id="T_8f8e7_row4_col0" class="data row4 col0" >83.37</td>
#       <td id="T_8f8e7_row4_col1" class="data row4 col1" >83.71</td>
#       <td id="T_8f8e7_row4_col2" class="data row4 col2" >84.29</td>
#       <td id="T_8f8e7_row4_col3" class="data row4 col3" >84.01</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#       <td id="T_8f8e7_row5_col0" class="data row5 col0" >80.87</td>
#       <td id="T_8f8e7_row5_col1" class="data row5 col1" >80.66</td>
#       <td id="T_8f8e7_row5_col2" class="data row5 col2" >81.40</td>
#       <td id="T_8f8e7_row5_col3" class="data row5 col3" >80.86</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row6" class="row_heading level0 row6" >Holden High School</th>
#       <td id="T_8f8e7_row6_col0" class="data row6 col0" >83.68</td>
#       <td id="T_8f8e7_row6_col1" class="data row6 col1" >83.32</td>
#       <td id="T_8f8e7_row6_col2" class="data row6 col2" >83.82</td>
#       <td id="T_8f8e7_row6_col3" class="data row6 col3" >84.70</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row7" class="row_heading level0 row7" >Huang High School</th>
#       <td id="T_8f8e7_row7_col0" class="data row7 col0" >81.29</td>
#       <td id="T_8f8e7_row7_col1" class="data row7 col1" >81.51</td>
#       <td id="T_8f8e7_row7_col2" class="data row7 col2" >81.42</td>
#       <td id="T_8f8e7_row7_col3" class="data row7 col3" >80.31</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row8" class="row_heading level0 row8" >Johnson High School</th>
#       <td id="T_8f8e7_row8_col0" class="data row8 col0" >81.26</td>
#       <td id="T_8f8e7_row8_col1" class="data row8 col1" >80.77</td>
#       <td id="T_8f8e7_row8_col2" class="data row8 col2" >80.62</td>
#       <td id="T_8f8e7_row8_col3" class="data row8 col3" >81.23</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row9" class="row_heading level0 row9" >Pena High School</th>
#       <td id="T_8f8e7_row9_col0" class="data row9 col0" >83.81</td>
#       <td id="T_8f8e7_row9_col1" class="data row9 col1" >83.61</td>
#       <td id="T_8f8e7_row9_col2" class="data row9 col2" >84.34</td>
#       <td id="T_8f8e7_row9_col3" class="data row9 col3" >84.59</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row10" class="row_heading level0 row10" >Rodriguez High School</th>
#       <td id="T_8f8e7_row10_col0" class="data row10 col0" >80.99</td>
#       <td id="T_8f8e7_row10_col1" class="data row10 col1" >80.63</td>
#       <td id="T_8f8e7_row10_col2" class="data row10 col2" >80.86</td>
#       <td id="T_8f8e7_row10_col3" class="data row10 col3" >80.38</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row11" class="row_heading level0 row11" >Shelton High School</th>
#       <td id="T_8f8e7_row11_col0" class="data row11 col0" >84.12</td>
#       <td id="T_8f8e7_row11_col1" class="data row11 col1" >83.44</td>
#       <td id="T_8f8e7_row11_col2" class="data row11 col2" >84.37</td>
#       <td id="T_8f8e7_row11_col3" class="data row11 col3" >82.78</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row12" class="row_heading level0 row12" >Thomas High School</th>
#       <td id="T_8f8e7_row12_col0" class="data row12 col0" >83.73</td>
#       <td id="T_8f8e7_row12_col1" class="data row12 col1" >84.25</td>
#       <td id="T_8f8e7_row12_col2" class="data row12 col2" >83.59</td>
#       <td id="T_8f8e7_row12_col3" class="data row12 col3" >83.83</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row13" class="row_heading level0 row13" >Wilson High School</th>
#       <td id="T_8f8e7_row13_col0" class="data row13 col0" >83.94</td>
#       <td id="T_8f8e7_row13_col1" class="data row13 col1" >84.02</td>
#       <td id="T_8f8e7_row13_col2" class="data row13 col2" >83.76</td>
#       <td id="T_8f8e7_row13_col3" class="data row13 col3" >84.32</td>
#     </tr>
#     <tr>
#       <th id="T_8f8e7_level0_row14" class="row_heading level0 row14" >Wright High School</th>
#       <td id="T_8f8e7_row14_col0" class="data row14 col0" >83.83</td>
#       <td id="T_8f8e7_row14_col1" class="data row14 col1" >83.81</td>
#       <td id="T_8f8e7_row14_col2" class="data row14 col2" >84.16</td>
#       <td id="T_8f8e7_row14_col3" class="data row14 col3" >84.07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# create spending bins
bins = [0, 584, 629, 644, 675]
group_name = ["<$584", "$585-629", "$630-644", "$645-675"]
sxhool_Student_data['spending_bins'] = pd.cut(sxhool_Student_data['budget']/sxhool_Student_data['size'], bins, labels = group_name)

#group by spending
by_spending = sxhool_Student_data.groupby('spending_bins')
avg_math = by_spending['math_score'].mean()
avg_read = by_spending['reading_score'].mean()
pass_math = sxhool_Student_data[sxhool_Student_data['math_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()*100
pass_read = sxhool_Student_data[sxhool_Student_data['reading_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()*100
overall = sxhool_Student_data[(sxhool_Student_data['reading_score'] >= 70) & (sxhool_Student_data['math_score'] >= 70)].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()*100
    
# df build            
scores_by_spend = pd.DataFrame({"Average Math Score": avg_math, "Average Reading Score": avg_read,"% Passing Math": pass_math,"% Passing Reading": pass_read,"% Overall Passing": overall})
            
#reorder columns
scores_by_spend = scores_by_spend[["Average Math Score","Average Reading Score","% Passing Math", "% Passing Reading","% Overall Passing"]]

scores_by_spend.index.name = "Per Student Budget"

#formating
scores_by_spend.style.format({'Average Math Score': '{:.2f}','Average Reading Score': '{:.2f}', '% Passing Reading':'{:.2f}','% Passing Math': '{:.2f}','% Overall Passing': '{:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_68795">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68795_level0_col0" class="col_heading level0 col0" >Average Math Score</th>
#       <th id="T_68795_level0_col1" class="col_heading level0 col1" >Average Reading Score</th>
#       <th id="T_68795_level0_col2" class="col_heading level0 col2" >% Passing Math</th>
#       <th id="T_68795_level0_col3" class="col_heading level0 col3" >% Passing Reading</th>
#       <th id="T_68795_level0_col4" class="col_heading level0 col4" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Per Student Budget</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68795_level0_row0" class="row_heading level0 row0" ><$584</th>
#       <td id="T_68795_row0_col0" class="data row0 col0" >83.36</td>
#       <td id="T_68795_row0_col1" class="data row0 col1" >83.96</td>
#       <td id="T_68795_row0_col2" class="data row0 col2" >93.70</td>
#       <td id="T_68795_row0_col3" class="data row0 col3" >96.69</td>
#       <td id="T_68795_row0_col4" class="data row0 col4" >90.64</td>
#     </tr>
#     <tr>
#       <th id="T_68795_level0_row1" class="row_heading level0 row1" >$585-629</th>
#       <td id="T_68795_row1_col0" class="data row1 col0" >79.98</td>
#       <td id="T_68795_row1_col1" class="data row1 col1" >82.31</td>
#       <td id="T_68795_row1_col2" class="data row1 col2" >79.11</td>
#       <td id="T_68795_row1_col3" class="data row1 col3" >88.51</td>
#       <td id="T_68795_row1_col4" class="data row1 col4" >70.94</td>
#     </tr>
#     <tr>
#       <th id="T_68795_level0_row2" class="row_heading level0 row2" >$630-644</th>
#       <td id="T_68795_row2_col0" class="data row2 col0" >77.82</td>
#       <td id="T_68795_row2_col1" class="data row2 col1" >81.30</td>
#       <td id="T_68795_row2_col2" class="data row2 col2" >70.62</td>
#       <td id="T_68795_row2_col3" class="data row2 col3" >82.60</td>
#       <td id="T_68795_row2_col4" class="data row2 col4" >58.84</td>
#     </tr>
#     <tr>
#       <th id="T_68795_level0_row3" class="row_heading level0 row3" >$645-675</th>
#       <td id="T_68795_row3_col0" class="data row3 col0" >77.05</td>
#       <td id="T_68795_row3_col1" class="data row3 col1" >81.01</td>
#       <td id="T_68795_row3_col2" class="data row3 col2" >66.23</td>
#       <td id="T_68795_row3_col3" class="data row3 col3" >81.11</td>
#       <td id="T_68795_row3_col4" class="data row3 col4" >53.53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# create size bins for 
bins = [0, 1000, 1999,5000]
group_name = ["Small (<1000)", "Medium (1000-2000)" , "Large (2000-5000)"]
sxhool_Student_data['size_bins'] = pd.cut(sxhool_Student_data['size'], bins, labels = group_name)

#group by spending
by_size = sxhool_Student_data.groupby('size_bins')

#calculations 
average_math_score = by_size['math_score'].mean()
average_reading_score = by_size['math_score'].mean()
pass_math_percent = sxhool_Student_data[sxhool_Student_data['math_score'] >= 70].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()*100
pass_read_percent = sxhool_Student_data[sxhool_Student_data['reading_score'] >= 70].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()*100
overall = sxhool_Student_data[(sxhool_Student_data['reading_score'] >= 70) & (sxhool_Student_data['math_score'] >= 70)].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()*100
  
# df build            
scores_by_size = pd.DataFrame({"Average Math Score": average_math_score,"Average Reading Score": average_reading_score,'% Passing Math': pass_math_percent,'% Passing Reading': pass_read_percent,'% Overall Passing': overall})
            
#reorder columns
scores_by_size = scores_by_size[["Average Math Score","Average Reading Score",'% Passing Math','% Passing Reading','% Overall Passing']]

scores_by_size.index.name = "Total Students"
scores_by_size = scores_by_size.reindex(group_name)

#formating
scores_by_size.style.format({'Average Math Score': '{:.2f}','Average Reading Score': '{:.2f}','% Passing Math': '{:.2f}', '% Passing Reading':'{:.2f}', '% Overall Passing': '{:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b347">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b347_level0_col0" class="col_heading level0 col0" >Average Math Score</th>
#       <th id="T_9b347_level0_col1" class="col_heading level0 col1" >Average Reading Score</th>
#       <th id="T_9b347_level0_col2" class="col_heading level0 col2" >% Passing Math</th>
#       <th id="T_9b347_level0_col3" class="col_heading level0 col3" >% Passing Reading</th>
#       <th id="T_9b347_level0_col4" class="col_heading level0 col4" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Total Students</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b347_level0_row0" class="row_heading level0 row0" >Small (<1000)</th>
#       <td id="T_9b347_row0_col0" class="data row0 col0" >83.83</td>
#       <td id="T_9b347_row0_col1" class="data row0 col1" >83.83</td>
#       <td id="T_9b347_row0_col2" class="data row0 col2" >93.95</td>
#       <td id="T_9b347_row0_col3" class="data row0 col3" >96.04</td>
#       <td id="T_9b347_row0_col4" class="data row0 col4" >90.14</td>
#     </tr>
#     <tr>
#       <th id="T_9b347_level0_row1" class="row_heading level0 row1" >Medium (1000-2000)</th>
#       <td id="T_9b347_row1_col0" class="data row1 col0" >83.37</td>
#       <td id="T_9b347_row1_col1" class="data row1 col1" >83.37</td>
#       <td id="T_9b347_row1_col2" class="data row1 col2" >93.62</td>
#       <td id="T_9b347_row1_col3" class="data row1 col3" >96.77</td>
#       <td id="T_9b347_row1_col4" class="data row1 col4" >90.62</td>
#     </tr>
#     <tr>
#       <th id="T_9b347_level0_row2" class="row_heading level0 row2" >Large (2000-5000)</th>
#       <td id="T_9b347_row2_col0" class="data row2 col0" >77.48</td>
#       <td id="T_9b347_row2_col1" class="data row2 col1" >77.48</td>
#       <td id="T_9b347_row2_col2" class="data row2 col2" >68.65</td>
#       <td id="T_9b347_row2_col3" class="data row2 col3" >82.13</td>
#       <td id="T_9b347_row2_col4" class="data row2 col4" >56.57</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# group by school type
schoo_type = sxhool_Student_data.groupby("type")

#calculations 
average_math_score = schoo_type['math_score'].mean()
average_reading_score = schoo_type['math_score'].mean()
pass_math_percent = sxhool_Student_data[sxhool_Student_data['math_score'] >= 70].groupby('type')['Student ID'].count()/schoo_type['Student ID'].count()*100
pass_read_percent = sxhool_Student_data[sxhool_Student_data['reading_score'] >= 70].groupby('type')['Student ID'].count()/schoo_type['Student ID'].count()*100
overall = sxhool_Student_data[(sxhool_Student_data['reading_score'] >= 70) & (sxhool_Student_data['math_score'] >= 70)].groupby('type')['Student ID'].count()/schoo_type['Student ID'].count()*100

# df build            
scores_school_type = pd.DataFrame({"Average Math Score": average_math_score,"Average Reading Score": average_reading_score,'% Passing Math': pass_math_percent,'% Passing Reading': pass_read_percent,"% Overall Passing": overall})
  
#reorder columns
scores_school_type = scores_school_type [["Average Math Score","Average Reading Score",'% Passing Math','% Passing Reading',"% Overall Passing"]]
scores_school_type.index.name = "Type of School"

#formating
scores_school_type.style.format({'Average Math Score': '{:.2f}', 'Average Reading Score': '{:.2f}', '% Passing Math': '{:.2f}', '% Passing Reading':'{:.2f}', '% Overall Passing': '{:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_af68b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af68b_level0_col0" class="col_heading level0 col0" >Average Math Score</th>
#       <th id="T_af68b_level0_col1" class="col_heading level0 col1" >Average Reading Score</th>
#       <th id="T_af68b_level0_col2" class="col_heading level0 col2" >% Passing Math</th>
#       <th id="T_af68b_level0_col3" class="col_heading level0 col3" >% Passing Reading</th>
#       <th id="T_af68b_level0_col4" class="col_heading level0 col4" >% Overall Passing</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Type of School</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af68b_level0_row0" class="row_heading level0 row0" >Charter</th>
#       <td id="T_af68b_row0_col0" class="data row0 col0" >83.41</td>
#       <td id="T_af68b_row0_col1" class="data row0 col1" >83.41</td>
#       <td id="T_af68b_row0_col2" class="data row0 col2" >93.70</td>
#       <td id="T_af68b_row0_col3" class="data row0 col3" >96.65</td>
#       <td id="T_af68b_row0_col4" class="data row0 col4" >90.56</td>
#     </tr>
#     <tr>
#       <th id="T_af68b_level0_row1" class="row_heading level0 row1" >District</th>
#       <td id="T_af68b_row1_col0" class="data row1 col0" >76.99</td>
#       <td id="T_af68b_row1_col1" class="data row1 col1" >76.99</td>
#       <td id="T_af68b_row1_col2" class="data row1 col2" >66.52</td>
#       <td id="T_af68b_row1_col3" class="data row1 col3" >80.91</td>
#       <td id="T_af68b_row1_col4" class="data row1 col4" >53.70</td>
#     </tr>
#   </tbody>
# </table>
